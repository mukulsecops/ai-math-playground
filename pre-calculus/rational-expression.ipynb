# %% [markdown]
# # Rational experssions excersices 1.4

# %%
from sympy import *
from IPython.display import Math

# %%
x,y,z,c,t,a,b,h,s,r,u,n,m = symbols('x,y,z,c,t,a,b,h,s,r,u,n,m')

# %% [markdown]
# ## Ques 7-16 - Simplify the rational expression

# %%
exprs = [
    cancel((3*(x + 2)*(x - 1)) / (6*(x - 1)**2)),
    cancel((4*(x**2 - 1)) / (12*(x + 2)*(x - 1))),
    cancel((x - 2) / (x**2 - 4)),
    cancel((x**2 - x - 2) / (x**2 - 1)),
    cancel((x**2 + 6*x + 8) / (x**2 + 5*x + 4)),
    cancel((x**2 - x - 12) / (x**2 + 5*x + 6)),
    cancel((y**2 + y) / (y**2 - 1)),
    # cancel((y**2 - 3*y - 18) / (2*y**2 + 5*y + 3)),
    factor(y**2 - 3*y - 18) / factor(2*y**2 + 5*y + 3),
    cancel((2*x**3 - x**2 - 6*x) / (2*x**2 - 7*x + 6)),
    cancel((1 - x**2) / (x**3 - 1)),
]

def gen_exprs(exprs, ques_start):
    for i, expr in enumerate(exprs, start=ques_start):
        display(Math(f"{i}: {latex(expr)}"))

gen_exprs(exprs, ques_start=7)
# Out:
# $\displaystyle 7: \frac{x + 2}{2 x - 2}$
# $\displaystyle 8: \frac{x + 1}{3 x + 6}$
# $\displaystyle 9: \frac{1}{x + 2}$
# $\displaystyle 10: \frac{x - 2}{x - 1}$
# $\displaystyle 11: \frac{x + 2}{x + 1}$
# $\displaystyle 12: \frac{x - 4}{x + 2}$
# $\displaystyle 13: \frac{y}{y - 1}$
# $\displaystyle 14: \frac{\left(y - 6\right) \left(y + 3\right)}{\left(y + 1\right) \left(2 y + 3\right)}$
# $\displaystyle 15: \frac{2 x^{2} + 3 x}{2 x - 3}$
# $\displaystyle 16: \frac{- x - 1}{x^{2} + x + 1}$

# %% [markdown]
# ## Ques. 17-30 . Perform the multiplication or division and simplify.

# %%
exprs_2 = [
    cancel(((4*x) / (x**2 - 4))*((x + 2)/(16*x))),
    cancel(((x**2 - 25) / (x**2 - 16))*((x + 4)/(x + 5))),
    cancel(((x**2 - x - 12) / (x**2 - 9))*((3 + x)/(4 - x))),
    cancel(((x**2 + 2*x - 3) / (x**2 - 2*x - 3))*((3 - x)/(3 + x))),
    cancel(((t - 3) / (t**2 + 9))*((t + 3)/(t**2 - 9))),
    cancel(((x**2 - x - 6) / (x**2 + 2*x))*((x**3 + x**2)/(x**2 - 2*x - 3))),
    cancel(((x**2 + 7*x + 12) / (x**2 + 3*x + 2))*((x**2 + 5*x + 6)/(x**2 + 6*x + 9))),
    cancel(((x**2 + 2*x*y + y**2) / (x**2 - y**2))*((2*x**2 - x*y - y**2)/(x**2 - x*y - 2*y**2))),
    cancel(((2*x**2 + 3*x + 1) / (x**2 + 2*x - 15))/((x**2 + 6*x + 5)/(2*x**2 - 7*x + 3))),
    cancel(((4*y**2 - 9) / (2*y**2 + 9*y - 18))/((2*y**2 + y - 3)/(y**2 + 5*y - 6))),
    cancel(((x**3) / (x + 1))/((x)/(x**2 + 2*x + 1))),
    cancel(((2*x**2 - 3*x - 2) / (x**2 - 1))/((2*x**2 + 5*x + 2)/(x**2 + x - 2))),
    cancel(((x) / (y))/(z)),
    cancel((x)/(y / z)),

]

gen_exprs(exprs_2, ques_start=17)
# Out:
# $\displaystyle 17: \frac{1}{4 x - 8}$
# $\displaystyle 18: \frac{x - 5}{x - 4}$
# $\displaystyle 19: \frac{- x - 3}{x - 3}$
# $\displaystyle 20: \frac{1 - x}{x + 1}$
# $\displaystyle 21: \frac{1}{t^{2} + 9}$
# $\displaystyle 22: x$
# $\displaystyle 23: \frac{x + 4}{x + 1}$
# $\displaystyle 24: \frac{2 x + y}{x - 2 y}$
# $\displaystyle 25: \frac{4 x^{2} - 1}{x^{2} + 10 x + 25}$
# $\displaystyle 26: 1$
# $\displaystyle 27: x^{3} + x^{2}$
# $\displaystyle 28: \frac{x - 2}{x + 1}$
# $\displaystyle 29: \frac{x}{y z}$
# $\displaystyle 30: \frac{x z}{y}$

# %% [markdown]
# ## Ques. 31-50 . Perform the addition or subtraction and simplify.

# %%
exprs_3 = [
    together(2 + ((x) / (x + 3))),
    together(((2*x - 1) / (x + 4)) - 1),
    together(((1) / (x + 5)) + ((2) / (x - 3))),
    cancel(together(((1) / (x + 1)) + ((1) / (x - 1)))),
    together(((1) / (x + 1)) - ((1) / (x + 2))),
    cancel(together(((x) / (x - 4)) - ((3) / (x + 6)))),
    together(((x) / (x + 1)**2) + ((2) / (x + 1))),
    cancel(together(((5) / (2*x - 3)) - ((3) / (2*x - 3)**2))),
    cancel(together((u + 1) + ((u) / (u + 1)))),
    together((2 / a**2) - (3 / (a*b)) + (4 / b**2)),
    together(((1) / (x**2)) + ((1) / (x**2 + x))),
    together((1 / x) + (1 / x**2) + (1 / x**3)),
    cancel(together(((2) / (x + 3)) - ((1) / (x**2 + 7*x + 12)))),
    cancel(together(((x) / (x**2 - 4)) + ((1) / (x - 2)))),
    cancel(together(((1) / (x + 3)) + ((1) / (x**2 - 9)))),
    cancel(together(((x) / (x**2 + x - 2)) - ((2) / (x**2 - 5*x + 4)))),
    together((2 / x) + (3 / (x - 1)) - (4 / (x**2 - x))),
    cancel(together((x / (x**2 - x - 6)) - (1 / (x + 2)) - (2 / (x - 3)))),
    cancel(together(((1) / (x**2 + 3*x + 2)) - ((1) / (x**2 - 2*x - 3)))),
    cancel((1 / (x + 1)) - (2 / (x + 1)**2) + (3 / (x**2 - 1))), # You can use simple cancel instead as it does together automatically.

]

gen_exprs(exprs_3, ques_start=31)
# Out:
# $\displaystyle 31: \frac{3 \left(x + 2\right)}{x + 3}$
# $\displaystyle 32: \frac{x - 5}{x + 4}$
# $\displaystyle 33: \frac{3 x + 7}{\left(x - 3\right) \left(x + 5\right)}$
# $\displaystyle 34: \frac{2 x}{x^{2} - 1}$
# $\displaystyle 35: \frac{1}{\left(x + 1\right) \left(x + 2\right)}$
# $\displaystyle 36: \frac{x^{2} + 3 x + 12}{x^{2} + 2 x - 24}$
# $\displaystyle 37: \frac{3 x + 2}{\left(x + 1\right)^{2}}$
# $\displaystyle 38: \frac{10 x - 18}{4 x^{2} - 12 x + 9}$
# $\displaystyle 39: \frac{u^{2} + 3 u + 1}{u + 1}$
# $\displaystyle 40: \frac{4 a^{2} - 3 a b + 2 b^{2}}{a^{2} b^{2}}$
# $\displaystyle 41: \frac{2 x + 1}{x^{2} \left(x + 1\right)}$
# $\displaystyle 42: \frac{x^{2} + x + 1}{x^{3}}$
# $\displaystyle 43: \frac{2 x + 7}{x^{2} + 7 x + 12}$
# $\displaystyle 44: \frac{2 x + 2}{x^{2} - 4}$
# $\displaystyle 45: \frac{x - 2}{x^{2} - 9}$
# $\displaystyle 46: \frac{x^{2} - 6 x - 4}{x^{3} - 3 x^{2} - 6 x + 8}$
# $\displaystyle 47: \frac{5 x - 6}{x \left(x - 1\right)}$
# ...

# %% [markdown]
# ## Ques. 51-60 . Simplify the compound fractional expression.

# %%
exprs_4 = [
    cancel(((x/y) - (y/x)) / ((1/x**2) - (1/y**2))),
    cancel((x) - ((y) / ((x/y) + (y/x)))),
    cancel(((1) + (1/(c-1))) / ((1) - (1/(c - 1)))),
    cancel((1) + (1/(1 + (1/(1+x))))),
    cancel(((5/(x-1)) - (2/(x+1))) / ((x/(x-1)) + (1/(x+1)))),
    cancel((((a-b)/a)-((a+b)/b)) / (((a-b)/b)+((a+b)/a))),
    cancel((x**(-2) - y**(-2))/(x**(-1)+y**(-1))),
    cancel((x**(-1)+y**(-1))/((x+y)**(-1))),
    cancel((1/(1+a**n))+(1/(1+a**(-n)))),
    cancel((((a+1/b)**m) * ((a - 1/b)**n)) / (((b + 1/a)**m)*((b-1/a)**n)))

]

gen_exprs(exprs_4, ques_start=51)
# Out:
# $\displaystyle 51: - x y$
# $\displaystyle 52: \frac{x^{3}}{x^{2} + y^{2}}$
# $\displaystyle 53: \frac{c}{c - 2}$
# $\displaystyle 54: \frac{2 x + 3}{x + 2}$
# $\displaystyle 55: \frac{3 x + 7}{x^{2} + 2 x - 1}$
# $\displaystyle 56: -1$
# $\displaystyle 57: \frac{- x + y}{x y}$
# $\displaystyle 58: \frac{x^{2} + 2 x y + y^{2}}{x y}$
# $\displaystyle 59: 1$
# $\displaystyle 60: \left(a - \frac{1}{b}\right)^{n} \left(a + \frac{1}{b}\right)^{m} \left(b - \frac{1}{a}\right)^{- n} \left(b + \frac{1}{a}\right)^{- m}$

# %% [markdown]
# ## Ques. 61-66 . Simplify the fractional expression. (Expressions like these arise in calculus.)

# %%
exprs_5 = [
    cancel(((1/(a+h))-(1/a))/(h)),
    cancel(((x+h)**(-3) - x**(-3))/(h)),
    cancel((((1-(x+h))/(2+(x+h))) - ((1-x)/(2+x)))/(h)),
    cancel(((x+h)**3 - 7*(x+h) - (x**3 - 7*x))/(h)),
    simplify(sqrt(1 + (x/sqrt(1-x**2))**2)),
    cancel(sqrt(1 + (x**3 - (1/(4*x**3)))**2))

]

gen_exprs(exprs_5, ques_start=61)
# Out:
# $\displaystyle 61: - \frac{1}{a^{2} + a h}$
# $\displaystyle 62: \frac{- h^{2} - 3 h x - 3 x^{2}}{h^{3} x^{3} + 3 h^{2} x^{4} + 3 h x^{5} + x^{6}}$
# $\displaystyle 63: - \frac{3}{h x + 2 h + x^{2} + 4 x + 4}$
# $\displaystyle 64: h^{2} + 3 h x + 3 x^{2} - 7$
# $\displaystyle 65: \sqrt{- \frac{1}{x^{2} - 1}}$
# $\displaystyle 66: \sqrt{x^{6} + \frac{1}{2} + \frac{1}{16 x^{6}}}$

# %% [markdown]
# ## Ques. 67-72 . Simplify the expression. (This type of expression arises in calculus when using the “quotient rule.”)

# %%
exprs_6 = [
    factor(cancel(((3*(x+2)**2*(x-3)**2) - ((x+2)**3*(2)*(x-3)))/((x - 3)**4))),
    factor(cancel(((2*x*(x+6)**4) - (x**2*(4)*(x+6)**3))/((x+6)**8))),
    factor(((2*(1+x)**Rational(1,2)) - (x*(1+x)**(-Rational(1,2))))/(x+1)),
    factor(cancel((((1-x**2)**Rational(1,2)) + (x**2*(1-x**2)**(-Rational(1,2)))) / (1-x**2))),
    factor(cancel(((3*(1+x)**Rational(1,3)) - (x*(1+x)**(-Rational(2,3)))) / ((1+x)**Rational(2,3)))),
    factor(cancel(((7 - 3*x)**Rational(1,2) + (Rational(3,2)*x*((7 - 3*x)**-Rational(1,2))))/(7 - 3*x)))

]

gen_exprs(exprs_6, ques_start=67)
# Out:
# $\displaystyle 67: \frac{\left(x - 13\right) \left(x + 2\right)^{2}}{\left(x - 3\right)^{3}}$
# $\displaystyle 68: - \frac{2 x \left(x - 6\right)}{\left(x + 6\right)^{5}}$
# $\displaystyle 69: \frac{x + 2}{\left(x + 1\right)^{\frac{3}{2}}}$
# $\displaystyle 70: - \frac{1}{\sqrt{- \left(x - 1\right) \left(x + 1\right)} \left(x - 1\right) \left(x + 1\right)}$
# $\displaystyle 71: \frac{2 x + 3}{\left(x + 1\right)^{\frac{4}{3}}}$
# $\displaystyle 72: \frac{3 x - 14}{2 \sqrt{7 - 3 x} \left(3 x - 7\right)}$

# %% [markdown]
# ## Ques. 73-78 . Rationalize the denominator.

# %%
exprs_7 = [
    simplify((1)/(2-sqrt(3))),
    radsimp((2)/(3-sqrt(5))),
    radsimp((2)/(sqrt(2)+sqrt(7))),
    radsimp((1)/(sqrt(x)+1)),
    radsimp((y)/(sqrt(3)+sqrt(y))),
    factor(radsimp((2*(x-y))/(sqrt(x)-sqrt(y)))),

]

gen_exprs(exprs_7, ques_start=73)
# Out:
# $\displaystyle 73: \sqrt{3} + 2$
# $\displaystyle 74: \frac{\sqrt{5} + 3}{2}$
# $\displaystyle 75: \frac{- 2 \sqrt{2} + 2 \sqrt{7}}{5}$
# $\displaystyle 76: \frac{\sqrt{x} - 1}{x - 1}$
# $\displaystyle 77: \frac{y^{\frac{3}{2}} - \sqrt{3} y}{y - 3}$
# $\displaystyle 78: \frac{2 \left(x^{\frac{3}{2}} - \sqrt{x} y + x \sqrt{y} - y^{\frac{3}{2}}\right)}{x - y}$

# %% [markdown]
# ## Ques. 78-84 . Rationalize the numerator.

# %%
# TODO: Not working using sympy - customize function needed to be build.

exprs_8 = [
    (1 - sqrt(5)) / 3,
    (sqrt(3) + sqrt(5)) / 2,
    (sqrt(r) + sqrt(2)) / 5,
    radsimp((sqrt(x) - sqrt(x + h)) / (h*sqrt(x)*sqrt(x + h))),
    sqrt(x**2 + 1) - x,
    sqrt(x  + 1) - sqrt(x)
]

gen_exprs(exprs_8, ques_start=78)
# Out:
# $\displaystyle 78: \frac{1}{3} - \frac{\sqrt{5}}{3}$
# $\displaystyle 79: \frac{\sqrt{3}}{2} + \frac{\sqrt{5}}{2}$
# $\displaystyle 80: \frac{\sqrt{r}}{5} + \frac{\sqrt{2}}{5}$
# $\displaystyle 81: \frac{- h \sqrt{x} - x^{\frac{3}{2}} + x \sqrt{h + x}}{h x \left(h + x\right)}$
# $\displaystyle 82: - x + \sqrt{x^{2} + 1}$
# $\displaystyle 83: - \sqrt{x} + \sqrt{x + 1}$

# %% [markdown]
# ## Ques. 85-92 . State whether the given equation is true for all values
# of the variables. (Disregard any value that makes a denominator
# zero.)

# %%
exprs_9 = [
    ((16 + a)/16) == (1 + (a/16)),
    (b / (b-c)) == (1 - (b/c)),
    (2 / (4 + x)) == (1/2 + 2/x),
    ((x+1) / (y+1)) == (x/y),
    (x/(x+y)) == (1/(1+y)),
    (2*(a/b)) == (2*a/2*b),
    ((-a)/b) == (-a/b),
    ((1 + x + x**2)/x) == together((1/x) + 1 + x)
]

gen_exprs(exprs_9, ques_start=85)
# Out:
# $\displaystyle 85: \text{True}$
# $\displaystyle 86: \text{False}$
# $\displaystyle 87: \text{False}$
# $\displaystyle 88: \text{False}$
# $\displaystyle 89: \text{False}$
# $\displaystyle 90: \text{False}$
# $\displaystyle 91: \text{True}$
# $\displaystyle 92: \text{True}$

# %% [markdown]
# ## Applications
